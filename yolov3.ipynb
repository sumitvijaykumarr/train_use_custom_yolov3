# %%
# !ls '/content/drive/MyDrive/yolov3'
# Out:
# backup	   chart_yolov3bySumit.png  custom_data.zip  result.txt  yolov3.ipynb
# chart.png  custom_data		    custom_weight    test

# %%
# !unzip '/content/drive/MyDrive/yolov3/custom_data.zip' -d '/content/drive/MyDrive/yolov3'
# Out:
# Archive:  /content/drive/MyDrive/yolov3/custom_data.zip
#    creating: /content/drive/MyDrive/yolov3/custom_data/
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_21_jpg.rf.3e36c4e8113618fe428d6e1f8afab575.txt
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_45_jpg.rf.1393c93abfdb9f2390c1c9fdfb895e67.jpg
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_63_jpg.rf.62fb2dea9cf3a39d961e0ae6f866a93b.txt
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_72_jpg.rf.4e60783761dcc0b01b67d5b09b24a1f0.jpg
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_108_jpg.rf.9e16bd7b27af7a2dd1e16e37d9ba8d76.jpg
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_110_jpg.rf.fdc2fddeab4a2bc26af34ff7efa4f343.jpg
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_110_jpg.rf.fdc2fddeab4a2bc26af34ff7efa4f343.txt
#   inflating: /content/drive/MyDrive/yolov3/custom_data/car_121_jpg.rf.5c230e8f6266ccbf7e58960ee5b8694e.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolov3/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolov3/darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Total 15395 (delta 0), reused 0 (delta 0), pack-reused 15395
# Receiving objects: 100% (15395/15395), 14.02 MiB | 7.09 MiB/s, done.
# Resolving deltas: 100% (10352/10352), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/yolov3/darknet
# Out:
# /content/drive/MyDrive/yolov3/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ...

# %%
# %cd /content/drive/MyDrive/yolov3
# Out:
# /content/drive/MyDrive/yolov3

# %%
# !ls
# Out:
# backup	custom_data  custom_data.zip  custom_weight  darknet  yolov3.ipynb

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3bySumit.cfg custom_weight/yolov3bySumit_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 36459, rewritten_bbox = 0.000000 %
#
#  1926: 0.361729, 0.323445 avg loss, 0.000100 rate, 9.570382 seconds, 61632 images, 0.279414 hours left
# Loaded: 0.000040 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.730147), count: 1, class_loss = 0.014251, iou_loss = 0.061581, total_loss = 0.075833
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.003476, iou_loss = 0.000000, total_loss = 0.003476
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 36460, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.846624), count: 2, class_loss = 0.190537, iou_loss = 0.321340, total_loss = 0.511877
# ...

# %%
# !darknet/darknet detector test custom_data/labelled_data.data /content/drive/MyDrive/yolov3/darknet/cfg/yolov3bySumit_last1.weights backup/yolov3bySumit_last.weights -dont_show <custom_data/test.txt> result.txt
# Out:
#  OpenCV isn't used - data augmentation will be slow
# Cannot load image "data/labels/32_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/33_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/34_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/35_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/36_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/37_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/38_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/39_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/40_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/41_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/42_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/43_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/44_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/45_0.png"
# ...
